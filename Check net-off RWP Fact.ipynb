# %%
# optimization for speed
# calculate first one-third, last one third to reduce workload
import pandas as pd 
import numpy as np
from itertools import combinations 
import xlrd
import pyxlsb
import datetime as dt


def right_find(policyCol, cpcAmountCol, accAmountCol):
    condition = [cpcAmountCol!=0 and accAmountCol==0 and policyCol.rfind('.')>policyCol.rfind('-'),
                cpcAmountCol!=0 and accAmountCol==0 and policyCol.rfind('.')<policyCol.rfind('-')]

    result=[policyCol[0:policyCol.rfind('.')],
            policyCol[0:policyCol.rfind('-')]]
    return np.select(condition,result,policyCol)

# Function to check if there is negative item
def check_negative(iterable):
    lst=[x for x in iterable if x<0]
    if len(lst)==1 and sum(iterable)<0:
        return False
    else:
        return True

# Function to create an iterable
def create_iterable(length):
    x=[i for i in range(length,1,-1)]
    y=[i for i in range(2,length+1)]
    z=list(zip(x,y))
    return [x for y in z for x in y][0:len(z)]

# Function to check net-off amount for Non Marine
def netOffCheckNonMarine(x,df,col,totalLimit):
    #col : columns to select
    #threshold : amount limit
    separateGroup=df.loc[x.index,col]
    separateGroup=separateGroup.sort_values(col)
    dict=separateGroup.to_dict()
    index_list=[]
    print('separateGroup:Checking...')
    print(separateGroup.head(1))
    print('\n')
    
    for i in create_iterable(len(dict[col[0]])):
        if len(dict[col[0]])>1 and check_negative(list(dict[col[1]].values()))==True:
            index_com=combinations(dict[col[0]].keys(),i)
            amount_com=combinations(dict[col[1]].values(),i)
            for j,k in zip(amount_com,index_com):
                # if first item of each combination > 0=> no net-off ( df is sorted ascending)
                if j[0]>0:
                    break
                #if sum of an array=0 and each array does not contain an item of another array
                if np.absolute(np.sum(np.array(j)))<=totalLimit and len([x for x in k if x in [ y for z in index_list for y in z]])==0:
                    index_list.append(k)
                    for l in k:
                        del dict[col[0]][l]
                        del dict[col[1]][l]

    index_list=[x for y in index_list for x in y]
    index_list.sort()
    index_list2=["Net-off" if i in index_list  else "" for i in x.index]
    print('Done!')
    return index_list2

def netOffCheckMarine(x,df,col,totalLimit,rowLimit):
    #col : columns to select
    #totalLimit : amount limit
    #rowLimit : total number of row to make combinations, if rowLimit> 30, if is very hard to calculate using PC
    separateGroup=df.loc[x.index,col]
    separateGroup=separateGroup.sort_values(col)
    dict=separateGroup.to_dict()
    index_list=[]
    print('separateGroup:Checking...')
    print(separateGroup.head(1))
    print('\n')
    for i in create_iterable(len(dict[col[0]])):
        if len(dict[col[0]])>1 and len(dict[col[0]])<rowLimit and check_negative(list(dict[col[1]].values()))==True:
            index_com=combinations(dict[col[0]].keys(),i)
            amount_com=combinations(dict[col[1]].values(),i)
            for j,k in zip(amount_com,index_com):
                  # if first item of each combination > 0=> no net-off ( df is sorted ascending)
                if j[0]>0:
                    break
                #if sum of an array=0 and each array does not contain an item of another array
                if np.absolute(np.sum(np.array(j)))<=totalLimit and len([x for x in k if x in [ y for z in index_list for y in z]])==0:
                    index_list.append(k)
                    for l in k:
                        del dict[col[0]][l]
                        del dict[col[1]][l]

    index_list=[x for y in index_list for x in y]
    index_list.sort()
    index_list2=["Net-off" if i in index_list  else "" for i in x.index]
    print('Done!')
    return index_list2

#Set threshold for Marine to filter marine policy with diff amount to 3% or bigger
marineThreshold=0.03 

# Read file ,dfMarinePolicy contains Marine Policy needs to be checked
fileLastMonth=r"D:\OneDrive\OneDrive - khoavanhoc.edu.vn\UIC\DOI CHIEU ACC-CPC\2020\01-10\Check RWP 01-10 2020.xlsb"
fileThisMonth=r"D:\OneDrive\OneDrive - khoavanhoc.edu.vn\UIC\DOI CHIEU ACC-CPC\2020\01-11\Check RWP 01-11 2020.xlsx"
fileLastMonth.replace('\\','/')
fileThisMonth.replace('\\','/')

dfCheckSQL=pd.read_excel(fileThisMonth,usecols=['Số đơn','Số đơn đến mã phòng','Mã nghiệp vụ ','Phòng','Phí nhượng TBH FAC CPC','Phí nhượng tái VND ACC','Chênh lệch VND','Final Note'])
dfCheckSQL['Số đơn']=dfCheckSQL['Số đơn'].str.upper()
dfCheckSQL['Số đơn đến mã phòng']=dfCheckSQL['Số đơn đến mã phòng'].str.upper()
dfCheckSQL['Số đơn']=dfCheckSQL['Số đơn'].fillna('NA')
dfCheckSQL['Số đơn đến mã phòng']=dfCheckSQL['Số đơn đến mã phòng'].fillna('NA')
dfCheckLastMonth=pd.read_excel(fileLastMonth,sheet_name='Sheet1',usecols=['Số đơn','Note'],skiprows=1,engine='pyxlsb')

# Clean dfCheckSQL
#dfCheckSQL['Số đơn']=dfCheckSQL['Số đơn'].str.strip() # clean white space
#dfCheckSQL['Số đơn đến mã phòng']=dfCheckSQL['Số đơn đến mã phòng'].str.strip() # clean white space
#dfCheckSQL['Số đơn']=np.where(dfCheckSQL['Số đơn'].str.contains('UPDATE'),dfCheckSQL['Số đơn'].str.slice(start=7),dfCheckSQL['Số đơn'])
#dfCheckSQL['Số đơn đến mã phòng']=np.where(dfCheckSQL['Số đơn đến mã phòng'].str.contains('UPDATE'),dfCheckSQL['Số đơn đến mã phòng'].str.slice(start=7),dfCheckSQL['Số đơn đến mã phòng'])
#MarinePolicy=pd.read_excel('D:/Check_GWP.xlsx',sheet_name='MarinePolicy').values()

# Define col for 02 groups
colNonMarine=['Số đơn đến mã phòng','Chênh lệch VND']
colMarine=['PolicyForChecking','Chênh lệch VND']

# Create df for Non Marine
dfNonMarine=dfCheckSQL.loc[(~dfCheckSQL['Mã nghiệp vụ '].isin(['MCA','ACA','MCE','MCI','ICA','COT',' MC']))&(dfCheckSQL['Final Note']).isin(['Check','Acc chưa ghi nhận','CLTG-Cargo'])]
#dfNonMarine=dfNonMarine.sort_values(colNonMarine)

dfNonMarine['Số đơn']=dfNonMarine['Số đơn'].str.strip() # clean white space
dfNonMarine['Số đơn đến mã phòng']=dfNonMarine['Số đơn đến mã phòng'].str.strip() # clean white space
dfNonMarine['Số đơn']=np.where(dfNonMarine['Số đơn'].str.contains('UPDATE'),dfNonMarine['Số đơn'].str.slice(start=7),dfNonMarine['Số đơn'])
dfNonMarine['Số đơn đến mã phòng']=np.where(dfNonMarine['Số đơn đến mã phòng'].str.contains('UPDATE'),dfNonMarine['Số đơn đến mã phòng'].str.slice(start=7),dfNonMarine['Số đơn đến mã phòng'])


# Create df for Marine
dfMarine=dfCheckSQL.loc[(dfCheckSQL['Mã nghiệp vụ '].isin(['MCA','ACA','MCE','MCI','ICA','COT',' MC']))&(dfCheckSQL['Final Note']).isin(['Check','Acc chưa ghi nhận','CLTG-Cargo'])]
#dfMarine=dfMarine.sort_values(colMarine)

# Create df group by for Marine
dfMarineGroupBy=dfMarine.groupby(['Số đơn đến mã phòng'],as_index=False)['Phí nhượng TBH FAC CPC','Phí nhượng tái VND ACC'].sum()
dfMarineGroupBy['PercentageDiff']=(2*(dfMarineGroupBy['Phí nhượng TBH FAC CPC']-dfMarineGroupBy['Phí nhượng tái VND ACC']+1)/(dfMarineGroupBy['Phí nhượng TBH FAC CPC']+dfMarineGroupBy['Phí nhượng tái VND ACC'])).abs()

marineList=dfMarineGroupBy.loc[dfMarineGroupBy['PercentageDiff']>marineThreshold,['Số đơn đến mã phòng']]
marineList=marineList['Số đơn đến mã phòng'].values

# Filter dfMarine 
dfMarineForChecking=dfMarine.loc[dfMarine['Số đơn đến mã phòng'].isin(marineList)]
dfMarineForChecking['Số đơn']=dfMarineForChecking['Số đơn'].str.strip() # clean white space
dfMarineForChecking['Số đơn đến mã phòng']=dfMarineForChecking['Số đơn đến mã phòng'].str.strip() # clean white space
dfMarineForChecking['Số đơn']=np.where(dfMarineForChecking['Số đơn'].str.contains('UPDATE'),dfMarineForChecking['Số đơn'].str.slice(start=7),dfMarineForChecking['Số đơn'])
dfMarineForChecking['Số đơn đến mã phòng']=np.where(dfMarineForChecking['Số đơn đến mã phòng'].str.contains('UPDATE'),dfMarineForChecking['Số đơn đến mã phòng'].str.slice(start=7),dfMarineForChecking['Số đơn đến mã phòng'])
dfMarineNOTForChecking=dfMarine.loc[~dfMarine['Số đơn đến mã phòng'].isin(marineList)]
dfMarineNOTForChecking['Check']=dfMarineNOTForChecking['Final Note']
dfMarineForChecking['PolicyForChecking']=dfMarineForChecking.apply(lambda x: right_find(x['Số đơn'],x['Phí nhượng TBH FAC CPC'],x['Phí nhượng tái VND ACC']),axis=1).astype(str)
#dfMarineForChecking=dfMarineForChecking.sort_values(colMarine)

# Create df for the rest
dfOk=dfCheckSQL.loc[(~dfCheckSQL['Final Note'].isin(['Check','Acc chưa ghi nhận','CLTG-Cargo']))]
dfOk['Check']=dfOk['Final Note']

# Create column for Marine policy

dfNonMarine['Check']=dfNonMarine.groupby([colNonMarine[0]])[colNonMarine[1]].transform(netOffCheckNonMarine,df=dfNonMarine,col=colNonMarine,totalLimit=10000)

dfMarineForChecking['Check']=dfMarineForChecking.groupby([colMarine[0]])[colMarine[1]].transform(netOffCheckMarine,df=dfMarineForChecking,col=colMarine,totalLimit=20000,rowLimit=101)

dfCheckFinal=pd.concat([dfNonMarine,dfMarineForChecking,dfMarineNOTForChecking,dfOk],axis=0)
dfCheckFinal['Note']=np.where(dfCheckFinal['Check']=='Net-off',dfCheckFinal['Check'],dfCheckFinal['Final Note'])
dfCheckFinal=dfCheckFinal.drop(columns=['Final Note','Check'])

dfCheckLastMonth=dfCheckLastMonth.rename(columns={'Final Note':'Note thang truoc'})
dfCheckFinal=dfCheckFinal.merge(dfCheckLastMonth, on='Số đơn',how='left')
time=str(dt.datetime.now()).replace(':','.')
dfCheckFinal.to_csv(f'D:/dfCheckFinal{time}.csv',encoding='utf-8-sig')
import subprocess
subprocess.Popen([f'D:/dfCheckFinal{time}.csv'],shell=True)
# Out:
# separateGroup:Checking...
#    Số đơn đến mã phòng  Chênh lệch VND
# 90        CPM170001HUR       -811192.0
#
#
# Done!
# separateGroup:Checking...
#             Số đơn đến mã phòng  Chênh lệch VND
# 7  EXCESS OF LOSS 2020_INTERNAL   -3.614658e+09
#
#
# Done!
# separateGroup:Checking...
#              Số đơn đến mã phòng  Chênh lệch VND
# 72  EXCESS OF LOSS 2020_MISC_MOT    -633495537.0
#
#
# Done!
# separateGroup:Checking...
#                      Số đơn đến mã phòng  Chênh lệch VND
# 158  EXCESS OF LOSS 2Q2020_FIR/ENG/CARGO   -3.333819e+09
#
#
# Done!
# separateGroup:Checking...
#           Số đơn đến mã phòng  Chênh lệch VND
# 73  EXCESS OF LOSS 2Q2020_MOT    -452110209.0
#
#
# Done!
# separateGroup:Checking...
#            Số đơn đến mã phòng  Chênh lệch VND
# 224  EXCESS OF LOSS 2Q2020_PAI    -228398746.0
#
#
# Done!
# separateGroup:Checking...
#                      Số đơn đến mã phòng  Chênh lệch VND
# 133  EXCESS OF LOSS 3Q2020_FIR/ENG/CARGO   -3.830102e+09
#
#
# Done!
# separateGroup:Checking...
#                 Số đơn đến mã phòng  Chênh lệch VND
# 105  EXCESS OF LOSS 4Q2019_INTERNAL      95568117.0
#
#
# Done!
# separateGroup:Checking...
#    Số đơn đến mã phòng  Chênh lệch VND
# 93        FAC1Q2019MOT     -60264247.0
#
#
# Done!
# separateGroup:Checking...
#     Số đơn đến mã phòng  Chênh lệch VND
# 165        FAC2Q2019MOT     -84246289.0
#
#
# Done!
# separateGroup:Checking...
#     Số đơn đến mã phòng  Chênh lệch VND
# 748        MCI190234SGD     -18777494.0
#
#
# Done!
# separateGroup:Checking...
#      Số đơn đến mã phòng  Chênh lệch VND
# 2261        MOT1Q2020FAC     -45421761.0
#
#
# Done!
# separateGroup:Checking...
#      Số đơn đến mã phòng  Chênh lệch VND
# 1773        MOT2Q2020FAC     -79274361.0
#
#
# Done!
# separateGroup:Checking...
#    Số đơn đến mã phòng  Chênh lệch VND
# 23                  NA      44429430.0
#
#
# Done!
# separateGroup:Checking...
#      Số đơn đến mã phòng  Chênh lệch VND
# 1975        PAR170208SBD      -1408950.0
#
#
# Done!
# separateGroup:Checking...
#      Số đơn đến mã phòng  Chênh lệch VND
# 1923        PAR190009SYF      60092481.0
#
#
# Done!
# separateGroup:Checking...
#      Số đơn đến mã phòng  Chênh lệch VND
# 1110        PAR190155HYD     926105.4424
#
#
# Done!
# separateGroup:Checking...
#     Số đơn đến mã phòng  Chênh lệch VND
# 876        PAR190158SGD       7568784.1
#
#
# Done!
# separateGroup:Checking...
#      Số đơn đến mã phòng  Chênh lệch VND
# 1395        PAR200010HYF    1.269212e+06
#
#
# Done!
# separateGroup:Checking...
#      Số đơn đến mã phòng  Chênh lệch VND
# 1471        PAR200029HBL     -59491807.0
#
#
# Done!
# separateGroup:Checking...
#      Số đơn đến mã phòng  Chênh lệch VND
# 1408        PNI200001HYL     276226763.4
#
#
# Done!
# separateGroup:Checking...
#      Số đơn đến mã phòng  Chênh lệch VND
# 1178        PNI200002HYL     226358281.8
#
#
# Done!
# separateGroup:Checking...
#      Số đơn đến mã phòng  Chênh lệch VND
# 1760        PNI200003HYL     275580610.2
#
#
# Done!
# separateGroup:Checking...
#      Số đơn đến mã phòng  Chênh lệch VND
# 1897        TRA140074HBD     -46527424.0
#
#
# Done!
# separateGroup:Checking...
#      Số đơn đến mã phòng  Chênh lệch VND
# 1950        TTY1Q2020ENG   -5.630532e+09
#
#
# Done!
# separateGroup:Checking...
#      Số đơn đến mã phòng  Chênh lệch VND
# 1999        TTY1Q2020FIR   -6.651584e+10
#
#
# Done!
# separateGroup:Checking...
#       Số đơn đến mã phòng  Chênh lệch VND
# 2186  TTY1Q2020FIR_KOREAN   -2.921924e+09
#
#
# Done!
# separateGroup:Checking...
#      Số đơn đến mã phòng  Chênh lệch VND
# 1009        TTY1Q2020MCA   -1.240001e+09
#
#
# Done!
# separateGroup:Checking...
#       Số đơn đến mã phòng  Chênh lệch VND
# 1968  TTY1Q2020MCA_KOREAN       8991709.0
#
#
# Done!
# separateGroup:Checking...
#      Số đơn đến mã phòng  Chênh lệch VND
# 1062        TTY1Q2020MIS   -6.990128e+09
#
#
# Done!
# separateGroup:Checking...
#      Số đơn đến mã phòng  Chênh lệch VND
# 1969        TTY2Q2020ENG   -4.873723e+09
#
#
# Done!
# separateGroup:Checking...
#      Số đơn đến mã phòng  Chênh lệch VND
# 1237        TTY2Q2020FIR   -7.535058e+10
#
#
# Done!
# separateGroup:Checking...
#       Số đơn đến mã phòng  Chênh lệch VND
# 1148  TTY2Q2020FIR_KOREAN   -2.455722e+09
#
#
# Done!
# separateGroup:Checking...
#      Số đơn đến mã phòng  Chênh lệch VND
# 1102  TTY2Q2020FIR_RETRO    -610238684.0
#
#
# Done!
# separateGroup:Checking...
#      Số đơn đến mã phòng  Chênh lệch VND
# 1676        TTY2Q2020MCA   -1.907198e+09
#
#
# Done!
# separateGroup:Checking...
#      Số đơn đến mã phòng  Chênh lệch VND
# 1933        TTY2Q2020MIS   -4.862993e+09
#
#
# Done!
# separateGroup:Checking...
#               Số đơn đến mã phòng  Chênh lệch VND
# 1758  TTY3Q2020ENGINEERINGSURPLUS   -6.318326e+09
#
#
# Done!
# separateGroup:Checking...
#                                 Số đơn đến mã phòng  Chênh lệch VND
# 2297  TTY3Q2020ENGINEERING_MISCELANCEOUS_CARGOFACOB    -464987051.0
#
#
# Done!
# separateGroup:Checking...
#       Số đơn đến mã phòng  Chênh lệch VND
# 1421  TTY3Q2020FIREFACOBG   -2.045069e+09
#
#
# Done!
# separateGroup:Checking...
#           Số đơn đến mã phòng  Chênh lệch VND
# 1308  TTY3Q2020FIREQUOTASHARE       2214860.0
#
#
# Done!
# separateGroup:Checking...
#        Số đơn đến mã phòng  Chênh lệch VND
# 2172  TTY3Q2020FIRESURPLUS   -4.551592e+10
#
#
# Done!
# separateGroup:Checking...
#      Số đơn đến mã phòng  Chênh lệch VND
# 2042        TTY3Q2020MCA     -43723616.0
#
#
# Done!
# separateGroup:Checking...
#       Số đơn đến mã phòng  Chênh lệch VND
# 1422  TTY3Q2020MCASURPLUS   -1.560654e+09
#
#
# Done!
# separateGroup:Checking...
#       Số đơn đến mã phòng  Chênh lệch VND
# 1103  TTY3Q2020SAFETYLINE    -143687652.0
#
#
# Done!
# separateGroup:Checking...
#                    Số đơn đến mã phòng  Chênh lệch VND
# 1726  TTY3Q2020WHOLEACCOUNTSURPLUS_ENG   -1.386950e+09
#
#
# Done!
# separateGroup:Checking...
#                    Số đơn đến mã phòng  Chênh lệch VND
# 1861  TTY3Q2020WHOLEACCOUNTSURPLUS_MIS   -5.949638e+09
#
#
# Done!
# separateGroup:Checking...
#       Số đơn đến mã phòng  Chênh lệch VND
# 1662  TTY4Q2019FIR(RETRO)       6007335.0
#
#
# Done!
# separateGroup:Checking...
#      Số đơn đến mã phòng  Chênh lệch VND
# 1835        WCI190415SYD     -14110635.0
#
#
# Done!
# separateGroup:Checking...
#      Số đơn đến mã phòng  Chênh lệch VND
# 1376        WCI200028HYD      -4898558.0
#
#
# Done!
# separateGroup:Checking...
#      Số đơn đến mã phòng  Chênh lệch VND
# 1707        WRH200001HYD    6.021237e+07
#
#
# Done!
# separateGroup:Checking...
#          PolicyForChecking  Chênh lệch VND
# 182  ICA200027SGD002EN0101       -839412.0
#
#
# Done!
# separateGroup:Checking...
#        PolicyForChecking  Chênh lệch VND
# 2227  ICA200027SGD02EN01       -839471.0
#
#
# Done!
# separateGroup:Checking...
#       PolicyForChecking  Chênh lệch VND
# 95  ICA200027SGD2020.07      -6878367.0
#
#
# Done!
# separateGroup:Checking...
#         PolicyForChecking  Chênh lệch VND
# 2228  ICA200027SGD2020.08     -48687366.0
#
#
# Done!
# separateGroup:Checking...
#        PolicyForChecking  Chênh lệch VND
# 183  ICA200027SGD2020.09     -52183489.0
#
#
# Done!
# separateGroup:Checking...
#      PolicyForChecking  Chênh lệch VND
# 8  ICA200027SGD2020.10     -29033249.0
#
#
# Done!
# separateGroup:Checking...
#        PolicyForChecking  Chênh lệch VND
# 248  ICA200027SGD2020.11     -24188020.0
#
#
# Done!
# separateGroup:Checking...
#       PolicyForChecking  Chênh lệch VND
# 594  MCA1408SBD2019.DEC      -1400984.0
#
#
# Done!
# separateGroup:Checking...
#       PolicyForChecking  Chênh lệch VND
# 217  MCA1408SBD2020.AUG       -459510.0
#
#
# Done!
# separateGroup:Checking...
#       PolicyForChecking  Chênh lệch VND
# 108  MCA1408SBD2020.FEB      -7265592.0
#
#
# Done!
# separateGroup:Checking...
#       PolicyForChecking  Chênh lệch VND
# 152  MCA1408SBD2020.JAN     -13726637.0
#
#
# Done!
# separateGroup:Checking...
#       PolicyForChecking  Chênh lệch VND
# 187  MCA1408SBD2020.JUL       -706012.0
#
#
# Done!
# separateGroup:Checking...
#                         PolicyForChecking  Chênh lệch VND
# 207  MCA1408SBD2020.MAR(LIST AS ATTACHED)     -21600417.0
#
#
# Done!
# separateGroup:Checking...
#             PolicyForChecking  Chênh lệch VND
# 2098  MCA1408SBD2020.MAR.EN01      17989106.0
#
#
# Done!
# separateGroup:Checking...
#            PolicyForChecking  Chênh lệch VND
# 253  MCA1408SBD2020.MAR.EN02       -585206.0
#
#
# Done!
# separateGroup:Checking...
#            PolicyForChecking  Chênh lệch VND
# 305  MCA1408SBD2020.MAY&JUNE        -45668.0
#
#
# Done!
# separateGroup:Checking...
#      PolicyForChecking  Chênh lệch VND
# 283  MCA1983HGD2019.12     -27838212.0
#
#
# Done!
# separateGroup:Checking...
#      PolicyForChecking  Chênh lệch VND
# 368  MCA1983HGD2020.01    -181597272.0
#
#
# Done!
# separateGroup:Checking...
#      PolicyForChecking  Chênh lệch VND
# 345  MCA1983HGD2020.02    -185571300.0
#
#
# Done!
# separateGroup:Checking...
#          PolicyForChecking  Chênh lệch VND
# 394  MCA1983HGD2020.02EN01      99253531.0
#
#
# Done!
# separateGroup:Checking...
#      PolicyForChecking  Chênh lệch VND
# 204  MCA1983HGD2020.03     -95151384.0
#
#
# Done!
# separateGroup:Checking...
#      PolicyForChecking  Chênh lệch VND
# 527  MCA1983HGD2020.04     -85388469.0
#
#
# Done!
# separateGroup:Checking...
#      PolicyForChecking  Chênh lệch VND
# 495  MCA1983HGD2020.05     -50619702.0
#
#
# Done!
# separateGroup:Checking...
#       PolicyForChecking  Chênh lệch VND
# 2004  MCA1983HGD2020.06     -46923653.0
#
#
# Done!
# separateGroup:Checking...
#      PolicyForChecking  Chênh lệch VND
# 341  MCA1983HGD2020.07     -54774555.0
#
#
# Done!
# separateGroup:Checking...
#      PolicyForChecking  Chênh lệch VND
# 275  MCA1983HGD2020.08     -74569878.0
#
#
# Done!
# separateGroup:Checking...
#         PolicyForChecking  Chênh lệch VND
# 419  MCA2000012HGD2020.09     -12226889.0
#
#
# Done!
# separateGroup:Checking...
#     PolicyForChecking  Chênh lệch VND
# 302   MCA200001SGD002       -386784.0
#
#
# Done!
# separateGroup:Checking...
#     PolicyForChecking  Chênh lệch VND
# 446   MCA200001SGD003       -855307.0
#
#
# Done!
# separateGroup:Checking...
#     PolicyForChecking  Chênh lệch VND
# 642   MCA200001SGD007      -1423193.0
#
#
# Done!
# separateGroup:Checking...
#     PolicyForChecking  Chênh lệch VND
# 910   MCA200001SGD008      -2946215.0
#
#
# Done!
# separateGroup:Checking...
#     PolicyForChecking  Chênh lệch VND
# 416   MCA200001SGD009      -1711043.0
#
#
# Done!
# separateGroup:Checking...
#      PolicyForChecking  Chênh lệch VND
# 1797   MCA200001SGD010      -3528668.0
#
#
# Done!
# separateGroup:Checking...
#     PolicyForChecking  Chênh lệch VND
# 543   MCA200001SGD012      -3406628.0
#
#
# Done!
# separateGroup:Checking...
#     PolicyForChecking  Chênh lệch VND
# 717   MCA200001SGD013      -5620170.0
#
#
# Done!
# separateGroup:Checking...
#     PolicyForChecking  Chênh lệch VND
# 690   MCA200001SGD014      -2871849.0
#
#
# Done!
# separateGroup:Checking...
#     PolicyForChecking  Chênh lệch VND
# 462   MCA200001SGD015      -5542972.0
#
#
# Done!
# separateGroup:Checking...
#     PolicyForChecking  Chênh lệch VND
# 710   MCA200002SGD001        -37424.0
#
#
# Done!
# separateGroup:Checking...
#     PolicyForChecking  Chênh lệch VND
# 560   MCA200002SGD002      -4444909.0
#
#
# Done!
# separateGroup:Checking...
#     PolicyForChecking  Chênh lệch VND
# 657   MCA200002SGD003      -3990362.0
#
#
# Done!
# separateGroup:Checking...
#     PolicyForChecking  Chênh lệch VND
# 806   MCA200002SGD007      -1631695.0
#
#
# Done!
# separateGroup:Checking...
#     PolicyForChecking  Chênh lệch VND
# 733   MCA200002SGD015      -3939504.0
#
#
# Done!
# separateGroup:Checking...
#     PolicyForChecking  Chênh lệch VND
# 995   MCA200002SGD019      -4412887.0
#
#
# Done!
# separateGroup:Checking...
#     PolicyForChecking  Chênh lệch VND
# 998  MCA200006SYCAR08      15262328.0
#
#
# Done!
# separateGroup:Checking...
#     PolicyForChecking  Chênh lệch VND
# 945  MCA200006SYCAR09       9334761.0
#
#
# Done!
# separateGroup:Checking...
#        PolicyForChecking  Chênh lệch VND
# 708  MCA200012HGD2020.09     -52983185.0
#
#
# Done!
# separateGroup:Checking...
#         PolicyForChecking  Chênh lệch VND
# 2246  MCA200012HGD2020.10     -45497504.0
#
#
# Done!
# separateGroup:Checking...
#     PolicyForChecking  Chênh lệch VND
# 947    MCA20002SGD018        -40635.0
#
#
# Done!
# separateGroup:Checking...
#         PolicyForChecking  Chênh lệch VND
# 833  MCI1190234SGD2020.01     -24974108.0
#
#
# Done!
# separateGroup:Checking...
#         PolicyForChecking  Chênh lệch VND
# 942  MCI1190234SGD2020.02     -13122453.0
#
#
# Done!
# separateGroup:Checking...
#         PolicyForChecking  Chênh lệch VND
# 436  MCI1190234SGD2020.03     -29433504.0
#
#
# Done!
# separateGroup:Checking...
#         PolicyForChecking  Chênh lệch VND
# 532  MCI130169SYD2020.APR      -1973272.0
#
#
# Done!
# separateGroup:Checking...
#         PolicyForChecking  Chênh lệch VND
# 497  MCI130169SYD2020.AUG       -201372.0
#
#
# Done!
# separateGroup:Checking...
#         PolicyForChecking  Chênh lệch VND
# 980  MCI130169SYD2020.FEB      -2635531.0
#
#
# Done!
# separateGroup:Checking...
#         PolicyForChecking  Chênh lệch VND
# 672  MCI130169SYD2020.JAN       -492097.0
#
#
# Done!
# separateGroup:Checking...
#          PolicyForChecking  Chênh lệch VND
# 2073  MCI130169SYD2020.JUL       -134966.0
#
#
# Done!
# separateGroup:Checking...
#                            PolicyForChecking  Chênh lệch VND
# 276  MCI130169SYD2020.MAR (AS LIST ATTACHED)     -12912471.0
#
#
# Done!
# separateGroup:Checking...
#               PolicyForChecking  Chênh lệch VND
# 2249  MCI130169SYD2020.MAY&JUNE     -38134644.0
#
#
# Done!
# separateGroup:Checking...
#         PolicyForChecking  Chênh lệch VND
# 533  MCI130169SYD2020.OCT       -269932.0
#
#
# Done!
# separateGroup:Checking...
#         PolicyForChecking  Chênh lệch VND
# 990  MCI130169SYD2020.SEP       -134966.0
#
#
# Done!
# separateGroup:Checking...
#         PolicyForChecking  Chênh lệch VND
# 1120  MCI190234SGD2020.05      -5589274.0
#
#
# Done!
# separateGroup:Checking...
#        PolicyForChecking  Chênh lệch VND
# 652  MCI190234SGD2020.06     -17842441.0
#
#
# Done!
# separateGroup:Checking...
#        PolicyForChecking  Chênh lệch VND
# 600  MCI190234SGD2020.07     -13872876.0
#
#
# Done!
# separateGroup:Checking...
#        PolicyForChecking  Chênh lệch VND
# 616  MCI190234SGD2020.09     -10541882.0
#
#
# Done!
# separateGroup:Checking...
#         PolicyForChecking  Chênh lệch VND
# 1132  MCI190234SGD2020.10      -7033802.0
#
#
# Done!
# separateGroup:Checking...
#     PolicyForChecking  Chênh lệch VND
# 860     MCI20438HYD.4     -45037950.0
#
#
# Done!
